# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
bubble_data = pd.read_excel("BubblesExcel2.xlsx")
bubble_data.head().T
# Out:
#                                                                        0  \
# StartDate                                                     Start Date
# EndDate                                                         End Date
# Status                                                     Response Type
# IPAddress                                                     IP Address
# Progress                                                        Progress
# Duration (in seconds)                              Duration (in seconds)
# Finished                                                        Finished
# RecordedDate                                               Recorded Date
# ResponseId                                                   Response ID
# RecipientLastName                                    Recipient Last Name
# RecipientFirstName                                  Recipient First Name
# RecipientEmail                                           Recipient Email
# ExternalReference                                External Data Reference
# LocationLatitude                                       Location Latitude
# LocationLongitude                                     Location Longitude
# DistributionChannel                                 Distribution Channel
# UserLanguage                                               User Language
# Q3                                       What gender do you identify as?
# Q4                                                     What is your age?
# Q5                     What college are you affiliated with at Carneg...
# Q7_1                   What is your political affiliation? - Politica...
# Q6                     What is your religious affiliation? - Selected...
# Q6_9_TEXT              What is your religious affiliation? - Other: -...
# Q8_1                   What is the strength of your religious affilia...
# Q9                                 What is your family household income?
# Q10                                              What is your ethnicity?
# Q11                    You have just graduated from an elite universi...
# Q20                      Briefly explain the logic behind your decision.
# Q12                    You’re in the market for a new brand of lipsti...
# Q21                      Briefly explain the logic behind your decision.
# Q13                    For years, you’ve been donating to your local ...
# Q22                      Briefly explain the logic behind your decision.
# Q14                    The company you are currently working at begin...
# Q23                      Briefly explain the logic behind your decision.
# Q19_1                  Rank the following values from 1 to 7 based on...
# Q19_2                  Rank the following values from 1 to 7 based on...
# Q19_3                  Rank the following values from 1 to 7 based on...
# Q19_4                  Rank the following values from 1 to 7 based on...
# Q19_5                  Rank the following values from 1 to 7 based on...
# Q19_6                  Rank the following values from 1 to 7 based on...
# Q19_7                  Rank the following values from 1 to 7 based on...
#
#                                                                        1  \
# StartDate                                            2019-10-23 15:25:11
# EndDate                                              2019-10-23 15:30:05
# Status                                                        IP Address
# IPAddress                                                 128.237.170.60
# Progress                                                             100
# Duration (in seconds)                                                294
# Finished                                                            True
# RecordedDate                                  2019-10-23 15:30:06.147000
# ResponseId                                             R_2wGmDIQ8EIbejyN
# RecipientLastName                                                    NaN
# RecipientFirstName                                                   NaN
# RecipientEmail                                                       NaN
# ExternalReference                                                    NaN
# LocationLatitude                                                     NaN
# LocationLongitude                                                    NaN
# DistributionChannel                                            anonymous
# UserLanguage                                                          EN
# Q3                                                                  Male
# Q4                                                                 18-24
# Q5                                             Tepper School of Buisness
# Q7_1                                                   Very Conservative
# Q6                                                              Catholic
# Q6_9_TEXT                                                            NaN
# Q8_1                                                   Moderate strength
# Q9                                                             >$150,000
# Q10                                                            Caucasian
# Q11                                                                  Yes
# Q20                    I don’t care about his personal life. It won’t...
# Q12                                                                  Yes
# Q21                                                             Quality
# Q13                                                                  Yes
# Q22                    Some people will really need the support that ...
# Q14                                                                  Yes
# Q23                    Career progression. I can do real volunteering...
# Q19_1                                                                  1
# Q19_2                                                                  7
# Q19_3                                                                  6
# Q19_4                                                                  4
# Q19_5                                                                  3
# Q19_6                                                                  5
# Q19_7                                                                  2
#
#                                                 2  \
# StartDate                     2019-10-23 15:39:47
# EndDate                       2019-10-23 15:41:32
# Status                                 IP Address
# IPAddress                           107.242.117.9
# Progress                                      100
# Duration (in seconds)                         105
# Finished                                     True
# RecordedDate           2019-10-23 15:41:33.030000
# ResponseId                      R_2xzcX5kr5rQKXeP
# RecipientLastName                             NaN
# RecipientFirstName                            NaN
# RecipientEmail                                NaN
# ExternalReference                             NaN
# LocationLatitude                              NaN
# LocationLongitude                             NaN
# DistributionChannel                     anonymous
# UserLanguage                                   EN
# Q3                                            NaN
# Q4                                            NaN
# Q5                                            NaN
# Q7_1                                          NaN
# Q6                                            NaN
# Q6_9_TEXT                                     NaN
# Q8_1                                          NaN
# Q9                                            NaN
# Q10                                           NaN
# Q11                                           NaN
# Q20                                           NaN
# Q12                                           NaN
# Q21                                           NaN
# Q13                                           NaN
# Q22                                           NaN
# Q14                                           NaN
# Q23                                           NaN
# Q19_1                                           2
# Q19_2                                           3
# Q19_3                                           4
# Q19_4                                           1
# Q19_5                                           5
# Q19_6                                           6
# Q19_7                                           7
#
#                                                                        3  \
# StartDate                                            2019-10-23 15:36:48
# EndDate                                              2019-10-23 15:51:08
# Status                                                        IP Address
# IPAddress                                                 128.237.124.47
# Progress                                                             100
# Duration (in seconds)                                                860
# Finished                                                            True
# RecordedDate                                  2019-10-23 15:51:08.888000
# ResponseId                                             R_2vkUsIdMKOovP8L
# RecipientLastName                                                    NaN
# RecipientFirstName                                                   NaN
# RecipientEmail                                                       NaN
# ExternalReference                                                    NaN
# LocationLatitude                                                     NaN
# LocationLongitude                                                    NaN
# DistributionChannel                                            anonymous
# UserLanguage                                                          EN
# Q3                                                                  Male
# Q4                                                                 18-24
# Q5                                             Mellon College of Science
# Q7_1                                                   Very Conservative
# Q6                                                             Christian
# Q6_9_TEXT                                                            NaN
# Q8_1                                                         Very Strong
# Q9                                                     $100,000-$150,000
# Q10                                                            Caucasian
# Q11                                                                  Yes
# Q20                    I am in favor of strengthening border control,...
# Q12                                                                   No
# Q21                    Since it’s not much more expensive, I would pr...
# Q13                                                                   No
# Q22                    If the soup kitchens are hindering the motivat...
# Q14                                                                   No
# Q23                    I feel like it would be a waste of time if we ...
# Q19_1                                                                  6
# Q19_2                                                                  4
# Q19_3                                                                  7
# Q19_4                                                                  2
# Q19_5                                                                  5
# Q19_6                                                                  3
# Q19_7                                                                  1
#
#                                                 4
# StartDate                     2019-10-23 17:48:44
# EndDate                       2019-10-23 17:49:43
# Status                                 IP Address
# IPAddress                          73.154.255.208
# Progress                                      100
# Duration (in seconds)                          59
# Finished                                     True
# RecordedDate           2019-10-23 17:49:43.969000
# ResponseId                      R_2uxhZhVvOgtf3CP
# RecipientLastName                             NaN
# RecipientFirstName                            NaN
# RecipientEmail                                NaN
# ExternalReference                             NaN
# LocationLatitude                              NaN
# LocationLongitude                             NaN
# DistributionChannel                     anonymous
# UserLanguage                                   EN
# Q3                                            NaN
# Q4                                            NaN
# Q5                                            NaN
# Q7_1                                          NaN
# Q6                                            NaN
# Q6_9_TEXT                                     NaN
# Q8_1                                          NaN
# Q9                                            NaN
# Q10                                           NaN
# Q11                                           NaN
# Q20                                           NaN
# Q12                                           NaN
# Q21                                           NaN
# Q13                                           NaN
# Q22                                           NaN
# Q14                                           NaN
# Q23                                           NaN
# Q19_1                                         NaN
# Q19_2                                         NaN
# Q19_3                                         NaN
# Q19_4                                         NaN
# Q19_5                                         NaN
# Q19_6                                         NaN
# Q19_7                                         NaN

# %% [markdown]
# ### Clean Dataframe
# #### Remove uneeded columns and rename

# %%
clean_data = bubble_data.drop(["StartDate", "EndDate", "Status", "Progress", 
                               "IPAddress", "Finished","RecordedDate","ResponseId", "RecipientLastName",
                              "RecipientFirstName","RecipientEmail","ExternalReference",
                              "LocationLatitude", "LocationLongitude","DistributionChannel",
                              "UserLanguage", ], axis=1)

column_names = ['Duration', 'Gender', 'Age', 'HomeCollege', 'Political', 'Religion', "ReligionOther",
               'ReligionStrength', 'HouseIncome', 'Ethnicity', 'Company', 'CompanyExplain', 'Lipstick', 
                'LipstickExplain', 'Soup', 'SoupExplain', 'Volunteer', 'VolunteerExplain', 'WealthRank', 'InclusivenessRank', 
                'StatusRank', 'CompassionRank', 'FairnessRank', 'GenerosityRank','CommitmentRank']
clean_data.columns = column_names
clean_data.head()
# Out:
#                 Duration                           Gender                Age  \
# 0  Duration (in seconds)  What gender do you identify as?  What is your age?
# 1                    294                             Male              18-24
# 2                    105                              NaN                NaN
# 3                    860                             Male              18-24
# 4                     59                              NaN                NaN
#
#                                          HomeCollege  \
# 0  What college are you affiliated with at Carneg...
# 1                          Tepper School of Buisness
# 2                                                NaN
# 3                          Mellon College of Science
# 4                                                NaN
#
#                                            Political  \
# 0  What is your political affiliation? - Politica...
# 1                                  Very Conservative
# 2                                                NaN
# 3                                  Very Conservative
# 4                                                NaN
#
#                                             Religion  \
# 0  What is your religious affiliation? - Selected...
# 1                                           Catholic
# 2                                                NaN
# 3                                          Christian
# 4                                                NaN
#
#                                        ReligionOther  \
# 0  What is your religious affiliation? - Other: -...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                     ReligionStrength  \
# 0  What is the strength of your religious affilia...
# 1                                  Moderate strength
# 2                                                NaN
# 3                                        Very Strong
# 4                                                NaN
#
#                              HouseIncome                Ethnicity  ...  \
# 0  What is your family household income?  What is your ethnicity?  ...
# 1                              >$150,000                Caucasian  ...
# 2                                    NaN                      NaN  ...
# 3                      $100,000-$150,000                Caucasian  ...
# 4                                    NaN                      NaN  ...
#
#                                          SoupExplain  \
# 0    Briefly explain the logic behind your decision.
# 1  Some people will really need the support that ...
# 2                                                NaN
# 3  If the soup kitchens are hindering the motivat...
# 4                                                NaN
#
#                                            Volunteer  \
# 0  The company you are currently working at begin...
# 1                                                Yes
# 2                                                NaN
# 3                                                 No
# 4                                                NaN
#
#                                     VolunteerExplain  \
# 0    Briefly explain the logic behind your decision.
# 1  Career progression. I can do real volunteering...
# 2                                                NaN
# 3  I feel like it would be a waste of time if we ...
# 4                                                NaN
#
#                                           WealthRank  \
# 0  Rank the following values from 1 to 7 based on...
# 1                                                  1
# 2                                                  2
# 3                                                  6
# 4                                                NaN
#
#                                    InclusivenessRank  \
# 0  Rank the following values from 1 to 7 based on...
# 1                                                  7
# 2                                                  3
# 3                                                  4
# 4                                                NaN
#
#                                           StatusRank  \
# 0  Rank the following values from 1 to 7 based on...
# 1                                                  6
# 2                                                  4
# 3                                                  7
# 4                                                NaN
#
#                                       CompassionRank  \
# 0  Rank the following values from 1 to 7 based on...
# 1                                                  4
# 2                                                  1
# 3                                                  2
# 4                                                NaN
#
#                                         FairnessRank  \
# 0  Rank the following values from 1 to 7 based on...
# 1                                                  3
# 2                                                  5
# 3                                                  5
# 4                                                NaN
#
#                                       GenerosityRank  \
# 0  Rank the following values from 1 to 7 based on...
# 1                                                  5
# 2                                                  6
# 3                                                  3
# 4                                                NaN
#
#                                       CommitmentRank
# 0  Rank the following values from 1 to 7 based on...
# 1                                                  2
# 2                                                  7
# 3                                                  1
# 4                                                NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Remove Bad Rows
# #### Remove description row and rows with low duration responses

# %%
clean_data = clean_data.iloc[1:]
clean_data = clean_data[ pd.to_numeric(clean_data['Duration']) > 120 ]
#clean_data[ clean_data['Age'] == 'NaN']

# %%
clean_data
# Out:
#     Duration  Gender    Age  \
# 1        294    Male  18-24
# 3        860    Male  18-24
# 5        150  Female  18-24
# 6        567    Male  18-24
# 7        856    Male  18-24
# ..       ...     ...    ...
# 112      430    Male  18-24
# 113     1167    Male  18-24
# 114      140  Female  18-24
# 115      693    Male  18-24
# 116     3398    Male  18-24
#
#                                            HomeCollege              Political  \
# 1                            Tepper School of Buisness      Very Conservative
# 3                            Mellon College of Science      Very Conservative
# 5    Dietrich College of Humanities and Social Scie...  Somewhat Conservative
# 6                           School of Computer Science       Somewhat Liberal
# 7                           School of Computer Science                    NaN
# ..                                                 ...                    ...
# 112                             College of Engineering               Moderate
# 113                             College of Engineering               Moderate
# 114                          Mellon College of Science       Somewhat Liberal
# 115                         School of Computer Science               Moderate
# 116                             College of Engineering           Very Liberal
#
#          Religion ReligionOther   ReligionStrength        HouseIncome  \
# 1        Catholic           NaN  Moderate strength          >$150,000
# 3       Christian           NaN        Very Strong  $100,000-$150,000
# 5       Christian           NaN        Very Strong          >$150,000
# 6       Christian           NaN        Very Strong           <$60,000
# 7       Christian           NaN    Little strength          >$150,000
# ..            ...           ...                ...                ...
# 112  Unaffiliated           NaN        No strength          >$150,000
# 113      Catholic           NaN  Moderate strength          >$150,000
# 114     Christian           NaN    Little strength          >$150,000
# 115  Unaffiliated           NaN        Very Strong          >$150,000
# 116     Christian           NaN        No strength          >$150,000
#
#            Ethnicity  ...                                        SoupExplain  \
# 1          Caucasian  ...  Some people will really need the support that ...
# 3          Caucasian  ...  If the soup kitchens are hindering the motivat...
# 5              Asian  ...                                                NaN
# 6              Asian  ...  In my understanding the soup kitchen could hel...
# 7    Hispanic/Latino  ...  The Catholic Church recently performed a study...
# ..               ...  ...                                                ...
# 112        Caucasian  ...  It is worthwhile to give back to the soup kitc...
# 113        Caucasian  ...  It still worth helping those people that are h...
# 114        Caucasian  ...                                                NaN
# 115            Asian  ...  If its inhibiting their ability to improve the...
# 116        Caucasian  ...  These people need food no matter what, I am go...
#
#     Volunteer                                   VolunteerExplain WealthRank  \
# 1         Yes  Career progression. I can do real volunteering...          1
# 3          No  I feel like it would be a waste of time if we ...          6
# 5          No                                                NaN          5
# 6         Yes  It's like a company paid holiday. I'm not tell...          6
# 7         Yes  Try to help them, who knows what will happen. ...        NaN
# ..        ...                                                ...        ...
# 112       Yes               I can enjoy a trip from time to time          7
# 113       Yes  It still is beneficial for my job and prioriti...          5
# 114       Yes                                                NaN          4
# 115       Yes  Vacation time. Theres no advantage to not goin...          3
# 116       Yes  It’s not like not going on the trip will help ...          3
#
#     InclusivenessRank StatusRank CompassionRank FairnessRank GenerosityRank  \
# 1                   7          6              4            3              5
# 3                   4          7              2            5              3
# 5                   7          4              2            6              1
# 6                   4          7              1            2              5
# 7                 NaN        NaN            NaN          NaN            NaN
# ..                ...        ...            ...          ...            ...
# 112                 5          6              1            3              4
# 113                 6          7              1            2              4
# 114                 5          7              3            6              1
# 115                 6          7              5            1              4
# 116                 5          7              6            1              4
#
#     CommitmentRank
# 1                2
# 3                1
# 5                3
# 6                3
# 7              NaN
# ..             ...
# 112              2
# 113              3
# 114              2
# 115              2
# 116              2
#
# [112 rows x 25 columns]

# %%
clean_data.head().T
# Out:
#                                                                    1  \
# Duration                                                         294
# Gender                                                          Male
# Age                                                            18-24
# HomeCollege                                Tepper School of Buisness
# Political                                          Very Conservative
# Religion                                                    Catholic
# ReligionOther                                                    NaN
# ReligionStrength                                   Moderate strength
# HouseIncome                                                >$150,000
# Ethnicity                                                  Caucasian
# Company                                                          Yes
# CompanyExplain     I don’t care about his personal life. It won’t...
# Lipstick                                                         Yes
# LipstickExplain                                             Quality
# Soup                                                             Yes
# SoupExplain        Some people will really need the support that ...
# Volunteer                                                        Yes
# VolunteerExplain   Career progression. I can do real volunteering...
# WealthRank                                                         1
# InclusivenessRank                                                  7
# StatusRank                                                         6
# CompassionRank                                                     4
# FairnessRank                                                       3
# GenerosityRank                                                     5
# CommitmentRank                                                     2
#
#                                                                    3  \
# Duration                                                         860
# Gender                                                          Male
# Age                                                            18-24
# HomeCollege                                Mellon College of Science
# Political                                          Very Conservative
# Religion                                                   Christian
# ReligionOther                                                    NaN
# ReligionStrength                                         Very Strong
# HouseIncome                                        $100,000-$150,000
# Ethnicity                                                  Caucasian
# Company                                                          Yes
# CompanyExplain     I am in favor of strengthening border control,...
# Lipstick                                                          No
# LipstickExplain    Since it’s not much more expensive, I would pr...
# Soup                                                              No
# SoupExplain        If the soup kitchens are hindering the motivat...
# Volunteer                                                         No
# VolunteerExplain   I feel like it would be a waste of time if we ...
# WealthRank                                                         6
# InclusivenessRank                                                  4
# StatusRank                                                         7
# CompassionRank                                                     2
# FairnessRank                                                       5
# GenerosityRank                                                     3
# CommitmentRank                                                     1
#
#                                                                    5  \
# Duration                                                         150
# Gender                                                        Female
# Age                                                            18-24
# HomeCollege        Dietrich College of Humanities and Social Scie...
# Political                                      Somewhat Conservative
# Religion                                                   Christian
# ReligionOther                                                    NaN
# ReligionStrength                                         Very Strong
# HouseIncome                                                >$150,000
# Ethnicity                                                      Asian
# Company                                                          Yes
# CompanyExplain                                                   NaN
# Lipstick                                                         Yes
# LipstickExplain                                                  NaN
# Soup                                                              No
# SoupExplain                                                      NaN
# Volunteer                                                         No
# VolunteerExplain                                                 NaN
# WealthRank                                                         5
# InclusivenessRank                                                  7
# StatusRank                                                         4
# CompassionRank                                                     2
# FairnessRank                                                       6
# GenerosityRank                                                     1
# CommitmentRank                                                     3
#
#                                                                    6  \
# Duration                                                         567
# Gender                                                          Male
# Age                                                            18-24
# HomeCollege                               School of Computer Science
# Political                                           Somewhat Liberal
# Religion                                                   Christian
# ReligionOther                                                    NaN
# ReligionStrength                                         Very Strong
# HouseIncome                                                 <$60,000
# Ethnicity                                                      Asian
# Company                                                          Yes
# CompanyExplain              The boss is gonna do what he's gonna do.
# Lipstick                                                          No
# LipstickExplain    Well if the animal testing was so popular and ...
# Soup                                                             Yes
# SoupExplain        In my understanding the soup kitchen could hel...
# Volunteer                                                        Yes
# VolunteerExplain   It's like a company paid holiday. I'm not tell...
# WealthRank                                                         6
# InclusivenessRank                                                  4
# StatusRank                                                         7
# CompassionRank                                                     1
# FairnessRank                                                       2
# GenerosityRank                                                     5
# CommitmentRank                                                     3
#
#                                                                    7
# Duration                                                         856
# Gender                                                          Male
# Age                                                            18-24
# HomeCollege                               School of Computer Science
# Political                                                        NaN
# Religion                                                   Christian
# ReligionOther                                                    NaN
# ReligionStrength                                     Little strength
# HouseIncome                                                >$150,000
# Ethnicity                                            Hispanic/Latino
# Company                                                          Yes
# CompanyExplain     I am grateful to be offered a job. I can talk ...
# Lipstick                                                          No
# LipstickExplain    It's an ugly thing to test stuff out on animal...
# Soup                                                             Yes
# SoupExplain        The Catholic Church recently performed a study...
# Volunteer                                                        Yes
# VolunteerExplain   Try to help them, who knows what will happen. ...
# WealthRank                                                       NaN
# InclusivenessRank                                                NaN
# StatusRank                                                       NaN
# CompassionRank                                                   NaN
# FairnessRank                                                     NaN
# GenerosityRank                                                   NaN
# CommitmentRank                                                   NaN

# %%
labels = ['Wealth',
          'Inclusiveness',
          'Status',
          'Compassion',
          'Fairness',
          'Generosity',
          'Commitment']
means = [np.mean(clean_data["WealthRank"]),
         np.mean(clean_data["InclusivenessRank"]),
         np.mean(clean_data["StatusRank"]),
         np.mean(clean_data["CompassionRank"]),
         np.mean(clean_data["FairnessRank"]),
         np.mean(clean_data["GenerosityRank"]),
         np.mean(clean_data["CommitmentRank"])]

x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots()
rects1 = ax.bar(x, means, width, label='Means')
ax.set_ylabel('Rank')
ax.set_title('Average Rank Ascribed to Each Value')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

fig.tight_layout()
plt.show()

# %%
male_data = clean_data[clean_data['Gender'] == 'Male']
female_data = clean_data[clean_data['Gender'] == 'Female']


male_means = [np.mean(male_data["WealthRank"]),
         np.mean(male_data["InclusivenessRank"]),
         np.mean(male_data["StatusRank"]),
         np.mean(male_data["CompassionRank"]),
         np.mean(male_data["FairnessRank"]),
         np.mean(male_data["GenerosityRank"]),
         np.mean(male_data["CommitmentRank"])]

female_means = [np.mean(female_data["WealthRank"]),
         np.mean(female_data["InclusivenessRank"]),
         np.mean(female_data["StatusRank"]),
         np.mean(female_data["CompassionRank"]),
         np.mean(female_data["FairnessRank"]),
         np.mean(female_data["GenerosityRank"]),
         np.mean(female_data["CommitmentRank"])]

x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, male_means, width, label='Male')
rects1 = ax.bar(x + width/2, female_means, width, label='Female')
ax.set_ylabel('Rank')
ax.set_title('Average Rank Ascribed to Each Value')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

fig.tight_layout()
plt.show()
