# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
bubble_data = pd.read_excel("BubblesExcel2.xlsx")
bubble_data.head().T
# Out:
#                                                                        0  \
# StartDate                                                     Start Date
# EndDate                                                         End Date
# Status                                                     Response Type
# IPAddress                                                     IP Address
# Progress                                                        Progress
# Duration (in seconds)                              Duration (in seconds)
# Finished                                                        Finished
# RecordedDate                                               Recorded Date
# ResponseId                                                   Response ID
# RecipientLastName                                    Recipient Last Name
# RecipientFirstName                                  Recipient First Name
# RecipientEmail                                           Recipient Email
# ...

# %% [markdown]
# ### Clean Dataframe
# #### Remove uneeded columns and rename

# %%
clean_data = bubble_data.drop(["StartDate", "EndDate", "Status", "Progress", 
                               "IPAddress", "Finished","RecordedDate","ResponseId", "RecipientLastName",
                              "RecipientFirstName","RecipientEmail","ExternalReference",
                              "LocationLatitude", "LocationLongitude","DistributionChannel",
                              "UserLanguage", ], axis=1)

column_names = ['Duration', 'Gender', 'Age', 'HomeCollege', 'Political', 'Religion', "ReligionOther",
               'ReligionStrength', 'HouseIncome', 'Ethnicity', 'Company', 'CompanyExplain', 'Lipstick', 
                'LipstickExplain', 'Soup', 'SoupExplain', 'Volunteer', 'VolunteerExplain', 'WealthRank', 'InclusivenessRank', 
                'StatusRank', 'CompassionRank', 'FairnessRank', 'GenerosityRank','CommitmentRank']
clean_data.columns = column_names
clean_data.head()
# Out:
#                 Duration                           Gender                Age  \
# 0  Duration (in seconds)  What gender do you identify as?  What is your age?
# 1                    294                             Male              18-24
# 2                    105                              NaN                NaN
# 3                    860                             Male              18-24
# 4                     59                              NaN                NaN
#
#                                          HomeCollege  \
# 0  What college are you affiliated with at Carneg...
# 1                          Tepper School of Buisness
# 2                                                NaN
# 3                          Mellon College of Science
# 4                                                NaN
#
#                                            Political  \
# 0  What is your political affiliation? - Politica...
# 1                                  Very Conservative
# ...

# %% [markdown]
# ### Remove Bad Rows
# #### Remove description row and rows with low duration responses

# %%
clean_data = clean_data.iloc[1:]
clean_data = clean_data[ pd.to_numeric(clean_data['Duration']) > 120 ]
# clean_data[ clean_data['Age'] == 'NaN']

# %%
clean_data.T
# Out:
#                                                                  1    \
# Duration                                                         294
# Gender                                                          Male
# Age                                                            18-24
# HomeCollege                                Tepper School of Buisness
# Political                                          Very Conservative
# Religion                                                    Catholic
# ReligionOther                                                    NaN
# ReligionStrength                                   Moderate strength
# HouseIncome                                                >$150,000
# Ethnicity                                                  Caucasian
# Company                                                          Yes
# CompanyExplain     I don’t care about his personal life. It won’t...
# Lipstick                                                         Yes
# ...

# %% [markdown]
# ## Word Cloud

# %%
def get_all_text(col):
    st = ""
    for item in col:
        st = st + str(item).strip() + ' '
    return st.strip()
    #return ''.join(str(col.values)).replace("\\","").replace('\n',' ').replace('"',"")[1:-1]
    
def writeFile(path, contents):
    with open(path, "wt") as f:
        f.write(contents)

# %%
company_yes = get_all_text( clean_data[ clean_data['Company'] == 'Yes']['CompanyExplain'] )
company_no = get_all_text( clean_data[ clean_data['Company'] == 'No']['CompanyExplain'] )
lipstick_yes = get_all_text( clean_data[ clean_data['Lipstick'] == 'Yes']['LipstickExplain'] )
lipstick_no = get_all_text( clean_data[ clean_data['Lipstick'] == 'No']['LipstickExplain'] )
soup_yes = get_all_text( clean_data[ clean_data['Soup'] == 'Yes']['SoupExplain'] )
soup_no = get_all_text( clean_data[ clean_data['Soup'] == 'No']['SoupExplain'] )
volunteer_yes = get_all_text( clean_data[ clean_data['Volunteer'] == 'Yes']['VolunteerExplain'] )
volunteer_no = get_all_text( clean_data[ clean_data['Volunteer'] == 'No']['VolunteerExplain'] )

writeFile('company_yes.txt', company_yes)
writeFile('company_no.txt', company_no)
writeFile('lipstick_yes.txt', lipstick_yes)
writeFile('lipstick_no.txt', lipstick_no)
writeFile('soup_yes.txt', soup_yes)
writeFile('soup_no.txt', soup_no)
writeFile('volunteer_yes.txt', volunteer_yes)
writeFile('volunteer_no.txt', volunteer_no)
